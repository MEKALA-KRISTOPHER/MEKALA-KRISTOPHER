# %% [markdown]
# <a href="https://colab.research.google.com/github/MEKALA-KRISTOPHER/MEKALA-KRISTOPHER/blob/main/CO2_emissions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#connect the drive to google.colab
from google.colab import drive

# %%
#set path of the CSV file
path ='/content/drive/MyDrive/emissions.csv.zip'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#        year state-name                                      sector-name  \
# 0      1970    Alabama              Industrial carbon dioxide emissions
# 1      1970    Alabama              Industrial carbon dioxide emissions
# 2      1970    Alabama              Industrial carbon dioxide emissions
# 3      1970    Alabama              Industrial carbon dioxide emissions
# 4      1970    Alabama  Total carbon dioxide emissions from all sectors
# ...     ...        ...                                              ...
# 59896  2021    Wyoming              Commercial carbon dioxide emissions
# 59897  2021    Wyoming             Residential carbon dioxide emissions
# 59898  2021    Wyoming             Residential carbon dioxide emissions
# 59899  2021    Wyoming             Residential carbon dioxide emissions
# 59900  2021    Wyoming  Total carbon dioxide emissions from all sectors
#
#          fuel-name       value
# 0             Coal   26.721507
# 1        Petroleum    3.577779
# ...

# %%
df.columns
# Out:
# Index(['year', 'state-name', 'sector-name', 'fuel-name', 'value'], dtype='object')

# %%
df['fuel-name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0               Coal
# 1          Petroleum
# 2        Natural Gas
# 3          All Fuels
# 4          All Fuels
#             ...
# 59896           Coal
# 59897      All Fuels
# 59898    Natural Gas
# 59899      Petroleum
# 59900      Petroleum
# Name: fuel-name, Length: 59901, dtype: object>

# %%
df['year'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1970
# 1        1970
# 2        1970
# 3        1970
# 4        1970
#          ...
# 59896    2021
# 59897    2021
# 59898    2021
# 59899    2021
# 59900    2021
# Name: year, Length: 59901, dtype: int64>

# %%
df['sector-name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                    Industrial carbon dioxide emissions
# 1                    Industrial carbon dioxide emissions
# 2                    Industrial carbon dioxide emissions
# 3                    Industrial carbon dioxide emissions
# 4        Total carbon dioxide emissions from all sectors
#                               ...
# 59896                Commercial carbon dioxide emissions
# 59897               Residential carbon dioxide emissions
# 59898               Residential carbon dioxide emissions
# 59899               Residential carbon dioxide emissions
# 59900    Total carbon dioxide emissions from all sectors
# Name: sector-name, Length: 59901, dtype: object>

# %%
df['state-name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Alabama
# 1        Alabama
# 2        Alabama
# 3        Alabama
# 4        Alabama
#           ...
# 59896    Wyoming
# 59897    Wyoming
# 59898    Wyoming
# 59899    Wyoming
# 59900    Wyoming
# Name: state-name, Length: 59901, dtype: object>

# %%
df['value'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         26.721507
# 1          3.577779
# 2          8.944097
# 3         39.243383
# 4        102.646851
#             ...
# 59896      0.012374
# 59897      0.937989
# 59898      0.717777
# 59899      0.220212
# 59900     10.198574
# Name: value, Length: 59901, dtype: float64>

# %%
df2 = df['state-name']

# %%
df2
# Out:
# 0        Alabama
# 1        Alabama
# 2        Alabama
# 3        Alabama
# 4        Alabama
#           ...
# 59896    Wyoming
# 59897    Wyoming
# 59898    Wyoming
# 59899    Wyoming
# 59900    Wyoming
# Name: state-name, Length: 59901, dtype: object

# %%
df3 = df['fuel-name']

# %%
df3
# Out:
# 0               Coal
# 1          Petroleum
# 2        Natural Gas
# 3          All Fuels
# 4          All Fuels
#             ...
# 59896           Coal
# 59897      All Fuels
# 59898    Natural Gas
# 59899      Petroleum
# 59900      Petroleum
# Name: fuel-name, Length: 59901, dtype: object

# %%
df6 = df['year'] > 2000

# %%
df6
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59896     True
# 59897     True
# 59898     True
# 59899     True
# 59900     True
# Name: year, Length: 59901, dtype: bool

# %%
df['fuel-name'].max()
# Out:
# 'Petroleum'

# %%
df['state-name'].max()
# Out:
# 'Wyoming'

# %%
df['value'].max()
# Out:
# 5996.429314

# %%
df.isna().sum()
# Out:
# year           0
# state-name     0
# sector-name    0
# fuel-name      0
# value          0
# dtype: int64

# %%
#Describe the file
df.describe()
# Out:
#                year         value
# count  59901.000000  59901.000000
# mean    1995.101067     35.647050
# std       14.922049    207.883289
# min     1970.000000      0.000022
# 25%     1982.000000      0.793179
# 50%     1995.000000      4.197628
# 75%     2008.000000     19.413459
# max     2021.000000   5996.429314

# %%
df1 = pd.crosstab(df["sector-name"], df["fuel-name"])
plt.show()

# %%
df1
# Out:
# fuel-name                                        All Fuels  Coal  Natural Gas  \
# sector-name
# Commercial carbon dioxide emissions                   2704  2078         2694
# Electric Power carbon dioxide emissions               2694  2406         2516
# Industrial carbon dioxide emissions                   2704  2467         2637
# Residential carbon dioxide emissions                  2704  1740         2694
# Total carbon dioxide emissions from all sectors       2704  2651         2694
# Transportation carbon dioxide emissions               2704   296         2612
#
# fuel-name                                        Petroleum
# sector-name
# Commercial carbon dioxide emissions                   2704
# Electric Power carbon dioxide emissions               2682
# Industrial carbon dioxide emissions                   2704
# Residential carbon dioxide emissions                  2704
# Total carbon dioxide emissions from all sectors       2704
# ...

# %%
df5 = df.groupby('state-name')

# %%
type(df5)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df.groupby('state-name')['value'].mean()
# Out:
# state-name
# Alabama                  20.849465
# Alaska                    5.693726
# Arizona                  13.191149
# Arkansas                  9.988808
# California               63.576063
# Colorado                 13.045395
# Connecticut               7.279575
# Delaware                  2.929727
# District of Columbia      1.063402
# Florida                  35.834985
# Georgia                  24.127550
# Hawaii                    4.310364
# Idaho                     2.624789
# Illinois                 38.832922
# Indiana                  34.755963
# Iowa                     12.215677
# Kansas                   12.083867
# Kentucky                 21.708451
# Louisiana                36.832603
# Maine                     3.403090
# Maryland                 12.308997
# Massachusetts            14.286738
# Michigan                 31.099540
# Minnesota                14.702458
# Mississippi              10.028999
# Missouri                 20.380596
# ...

# %%
df.groupby('state-name')['value'].count()
# Out:
# state-name
# Alabama                 1176
# Alaska                  1161
# Arizona                 1133
# Arkansas                1124
# California              1136
# Colorado                1188
# Connecticut             1135
# Delaware                1144
# District of Columbia     979
# Florida                 1139
# Georgia                 1180
# Hawaii                   899
# Idaho                   1105
# Illinois                1190
# Indiana                 1190
# Iowa                    1190
# Kansas                  1158
# Kentucky                1190
# Louisiana               1081
# Maine                   1120
# Maryland                1184
# Massachusetts           1162
# Michigan                1185
# Minnesota               1189
# Mississippi             1119
# Missouri                1190
# Montana                 1187
# Nebraska                1170
# Nevada                  1160
# New Hampshire           1122
# New Jersey              1158
# ...

# %%
df.groupby('state-name')['value'].max()
# Out:
# state-name
# Alabama                  147.287643
# Alaska                    47.490384
# Arizona                  102.612853
# Arkansas                  70.785991
# California               402.553429
# Colorado                  99.331120
# Connecticut               48.576991
# Delaware                  19.130792
# District of Columbia      13.641821
# Florida                  260.033845
# Georgia                  185.619260
# Hawaii                    23.996209
# Idaho                     20.522135
# Illinois                 258.842767
# Indiana                  240.055900
# Iowa                      90.320166
# Kansas                    79.041986
# Kentucky                 158.732956
# Louisiana                221.410944
# Maine                     24.070584
# Maryland                  85.005532
# Massachusetts            103.889965
# Michigan                 199.977990
# Minnesota                101.930910
# Mississippi               69.796767
# ...

# %%
df.groupby('state-name')['fuel-name']

# %%
df.shape
# Out:
# (59901, 5)

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['state-name'],df['value'],color = 'blue')
plt.xlabel('State Name ')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.title('State Name and Value')
plt.show()
# Out:
# <ipython-input-94-e9ae4db66d3f>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.scatter(df['fuel-name'],df['value'],color = 'blue')
plt.xlabel('fuel-name')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.title('State Name and Value')
plt.show()
# Out:
# <ipython-input-40-ee33a541fbee>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Calculate the value counts for each fuel type
fuel_counts = df['fuel-name'].value_counts()

# %%
filteredData = fuel_counts

# %%
filteredData.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
State_counts = df['state-name'].value_counts()

# %%
filteredData = State_counts.head(10)

# %%
filteredData.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.bar(df['fuel-name'],df['value'],color = 'blue')
plt.xlabel('fuel-name')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.title('Fuel Name and Value')
plt.show()
# Out:
# <ipython-input-74-9774eb353cc5>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.bar(df['year'],df['value'],color = 'blue')
plt.xlabel('Year')
plt.ylabel('value')
plt.legend()
plt.grid(True)
plt.title('Year and value')
plt.show()
# Out:
# <ipython-input-95-7bf42fefa349>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.scatter(df['year'],df['value'],color = 'red')
plt.xlabel('Year')
plt.ylabel('value')
plt.legend()
plt.grid(True)
plt.title('Year and value')
plt.show()
# Out:
# <ipython-input-97-32bedddf88e4>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
